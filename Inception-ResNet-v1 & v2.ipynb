# %%
import glob
import math
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import random
import sklearn.metrics as metrics

from tensorflow.keras import optimizers
from tensorflow.keras import backend
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, LearningRateScheduler
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import add, concatenate, Conv2D, Dense, Dropout, Flatten, Input, Lambda
from tensorflow.keras.layers import Activation, AveragePooling2D, BatchNormalization, MaxPooling2D, ZeroPadding2D
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical


# %matplotlib inline

# %%
imgrows=299
imgclms=299
channel=3

# %%
def stem_block(inputs,
         names=None):
    x = inputs
    
    x = Conv2D(filters=32, kernel_size=(3, 3), strides=2, padding='valid')(x)
    x = Conv2D(filters=32, kernel_size=(3, 3), strides=1, padding='valid')(x)
    x = Conv2D(filters=64, kernel_size=(3, 3), strides=1, padding='same')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=2, padding='valid')(x)
    x = Conv2D(filters=80, kernel_size=(1, 1), strides=1, padding='same')(x)
    x = Conv2D(filters=192, kernel_size=(3, 3), strides=1, padding='valid')(x)
    x = Conv2D(filters=256, kernel_size=(3, 3), strides=2, padding='valid')(x)

    return x

# %%
def stem_block(inputs,
         names=None):
    x = inputs
    
    x = Conv2D(filters=32, kernel_size=(3, 3), strides=2, padding='valid')(inputs)
    x = Conv2D(filters=32, kernel_size=(3, 3), strides=1, padding='valid')(x)
    x = Conv2D(filters=64, kernel_size=(3, 3), strides=1, padding='same')(x)
    x_L1_1 = MaxPooling2D(pool_size=(3, 3), strides=2, padding='valid')(x)
    x_R1_1 = Conv2D(filters=96, kernel_size=(3, 3), strides=2, padding='valid')(x)
    x = concatenate([x_L1_1, x_R1_1])
    
    x_L2_1 = Conv2D(filters=64, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_L2_2 = Conv2D(filters=96, kernel_size=(3, 3), strides=1, padding='valid')(x_L2_1)
    
    x_R2_1 = Conv2D(filters=64, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_R2_2 = Conv2D(filters=64, kernel_size=(7, 1), strides=1, padding='same')(x_R2_1)
    x_R2_3 = Conv2D(filters=64, kernel_size=(1, 7), strides=1, padding='same')(x_R2_2)
    x_R2_4 = Conv2D(filters=96, kernel_size=(3, 3), strides=1, padding='valid')(x_R2_3)
    x = concatenate([x_L2_2, x_R2_4])
    
    x_L3_1 = Conv2D(filters=192, kernel_size=(3, 3), strides=2, padding='valid')(x)
    x_R3_1 = MaxPooling2D(strides=2, padding='valid')(x)
    x = concatenate([x_L3_1, x_R3_1])
    return x

def inception_resnet_v2_a_block(inputs,
                                scale=0.1,
                                names=None):
    x = inputs
    
    x_L_1 = Conv2D(filters=32, kernel_size=(1, 1), strides=1, padding='same')(x)
    
    x_M_1 = Conv2D(filters=32, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_M_2 = Conv2D(filters=32, kernel_size=(3, 3), strides=1, padding='same')(x_M_1)
    
    x_R_1 = Conv2D(filters=32, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_R_2 = Conv2D(filters=48, kernel_size=(3, 3), strides=1, padding='same')(x_R_1)
    x_R_3 = Conv2D(filters=64, kernel_size=(3, 3), strides=1, padding='same')(x_R_2)
    
    x_C_1 = concatenate([x_L_1, x_M_2, x_R_3])
    x_C_2 = Conv2D(filters=384, kernel_size=(1, 1), padding='same', activation='linear')(x_C_1)
    
    x = Lambda(lambda ipt, scale: ipt[0] + ipt[1] * scale,
                      output_shape=backend.int_shape(x)[1:],
                      arguments={'scale': scale})([x, x_C_2])
    x = Activation(activation='relu')(x)
    return x

def inception_resnet_v2_b_block(inputs,
                                scale=0.1,
                                names=None):
    x = inputs

    x_L_1 = Conv2D(filters=192, kernel_size=(1, 1), strides=1, padding='same')(x)
    
    x_R_1 = Conv2D(filters=128, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_R_2 = Conv2D(filters=160, kernel_size=(1, 7), strides=1, padding='same')(x_R_1)
    x_R_3 = Conv2D(filters=192, kernel_size=(7, 1), strides=1, padding='same')(x_R_2)
    
    x_C_1 = concatenate([x_L_1, x_R_3])
    x_C_2 = Conv2D(filters=1152, kernel_size=(1, 1), padding='same', activation='linear')(x_C_1)

    x = Lambda(lambda ipt, scale: ipt[0] + ipt[1] * scale,
                      output_shape=backend.int_shape(x)[1:],
                      arguments={'scale': scale})([x, x_C_2])
    x = Activation(activation='relu')(x)
    return x

def inception_resnet_v2_c_block(inputs,
                                scale=0.1,
                                names=None):
    x = inputs

    x_L_1 = Conv2D(filters=192, kernel_size=(1, 1), strides=1, padding='same')(x)
    
    x_R_1 = Conv2D(filters=192, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_R_2 = Conv2D(filters=224, kernel_size=(1, 3), strides=1, padding='same')(x_R_1)
    x_R_3 = Conv2D(filters=256, kernel_size=(3, 1), strides=1, padding='same')(x_R_2)
    
    x_C_1 = concatenate([x_L_1, x_R_3])
    x_C_2 = Conv2D(filters=2048, kernel_size=(1, 1), padding='same', activation='linear')(x_C_1)
    
    x = Lambda(lambda ipt, scale: ipt[0] + ipt[1] * scale,
                      output_shape=backend.int_shape(x)[1:],
                      arguments={'scale': scale})([x, x_C_2])
    x = Activation(activation='relu')(x)
    return x

def reduction_a_block(inputs,
                      network_selected="Inception-v4",
                      names=None):
    if network_selected == "Inception-v4":
        k, l, m, n = 192, 224, 256, 384
    elif network_selected == "Inception-ResNet-v1":
        k, l, m, n = 192, 192, 256, 384
    elif network_selected == "Inception-ResNet-v2":
        k, l, m, n = 256, 256, 384, 384
        
    x = inputs
    
    x_L_1 = MaxPooling2D(pool_size=(3, 3), strides=2, padding='valid')(x)
    
    x_M_1 = Conv2D(filters=n, kernel_size=(3, 3), strides=2, padding='valid')(x)
    
    x_R_1 = Conv2D(filters=k, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_R_2 = Conv2D(filters=l, kernel_size=(3, 3), strides=1, padding='same')(x_R_1)
    x_R_3 = Conv2D(filters=m, kernel_size=(3, 3), strides=2, padding='valid')(x_R_2)
    
    x = concatenate([x_L_1, x_M_1, x_R_3])
    return x

def inception_resnet_v2_reduction_b_block(inputs,
                      names=None):   
    x = inputs
    
    x_EL_1 = MaxPooling2D(pool_size=(3, 3), strides=2, padding='valid')(x)
    
    x_ML_1 = Conv2D(filters=256, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_ML_2 = Conv2D(filters=384, kernel_size=(3, 3), strides=2, padding='valid')(x_ML_1)
    
    x_MR_1 = Conv2D(filters=256, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_MR_2 = Conv2D(filters=256, kernel_size=(3, 3), strides=2, padding='valid')(x_MR_1)
    
    x_ER_1 = Conv2D(filters=256, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_ER_2 = Conv2D(filters=256, kernel_size=(3, 3), strides=1, padding='same')(x_ER_1)
    x_ER_3 = Conv2D(filters=256, kernel_size=(3, 3), strides=2, padding='valid')(x_ER_2)
    
    x = concatenate([x_EL_1, x_ML_2, x_MR_2, x_ER_3])
    return x

def create_inception_resnet_v2(inputShape=(imgrows, imgclms, channel),
                   num_classes=2):
    NETWORK_SELECTED = "Inception-ResNet-v2"
    num_classes=1000
    inputs = Input(shape=inputShape)
    x = stem_block(inputs)
    x = inception_resnet_v2_a_block(x, scale=0.1)
    x = inception_resnet_v2_a_block(x, scale=0.1)
    x = inception_resnet_v2_a_block(x, scale=0.1)
    x = inception_resnet_v2_a_block(x, scale=0.1)
    x = inception_resnet_v2_a_block(x, scale=0.1)
    x = reduction_a_block(x, network_selected=NETWORK_SELECTED)
    
    x = inception_resnet_v2_b_block(x, scale=0.1)
    x = inception_resnet_v2_b_block(x, scale=0.1)
    x = inception_resnet_v2_b_block(x, scale=0.1)
    x = inception_resnet_v2_b_block(x, scale=0.1)
    x = inception_resnet_v2_b_block(x, scale=0.1)
    x = inception_resnet_v2_b_block(x, scale=0.1)
    x = inception_resnet_v2_b_block(x, scale=0.1)
    x = inception_resnet_v2_b_block(x, scale=0.1)
    x = inception_resnet_v2_b_block(x, scale=0.1)
    x = inception_resnet_v2_b_block(x, scale=0.1)
    x = inception_resnet_v2_reduction_b_block(x)
    
    x = inception_resnet_v2_c_block(x, scale=0.1)
    x = inception_resnet_v2_c_block(x, scale=0.1)
    x = inception_resnet_v2_c_block(x, scale=0.1)
    x = inception_resnet_v2_c_block(x, scale=0.1)
    x = inception_resnet_v2_c_block(x, scale=0.1)
    x = AveragePooling2D()(x)
    x = Flatten()(x)
    x = Dense(1792)(x)
    x = Dropout(0.2)(x)
    outputs = Dense(num_classes, activation='softmax', 
                    kernel_initializer='he_normal')(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(loss='categorical_crossentropy', 
                  optimizer="Adam", 
                  metrics=['accuracy'])
    return model


model = create_inception_resnet_v2()

# inputShape=(imgrows, imgclms, channel)
# inputs = Input(shape=inputShape)
# x = stem_block(inputs)
# x = inception_resnet_v2_a_block(x)
# x = inception_resnet_v2_a_block(x)
# x = inception_resnet_v2_a_block(x)
# x = inception_resnet_v2_a_block(x)
# x = inception_resnet_v2_a_block(x)
# x = reduction_a_block(x, network_selected="Inception-ResNet-v2")
# model = Model(inputs=inputs, outputs=x)
# model.compile(loss='categorical_crossentropy', 
#               optimizer="Adam", 
#               metrics=['accuracy'])
    
model.summary()
# Out:
# WARNING:tensorflow:From D:\DocumentsDDrive\Installed_Files\Anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\keras\initializers.py:104: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with distribution=normal is deprecated and will be removed in a future version.
# Instructions for updating:
# `normal` is a deprecated alias for `truncated_normal`
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_36 (InputLayer)           (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv2d_1681 (Conv2D)            (None, 149, 149, 32) 896         input_36[0][0]
# __________________________________________________________________________________________________
# conv2d_1682 (Conv2D)            (None, 147, 147, 32) 9248        conv2d_1681[0][0]
# __________________________________________________________________________________________________
# conv2d_1683 (Conv2D)            (None, 147, 147, 64) 18496       conv2d_1682[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_94 (MaxPooling2D) (None, 73, 73, 64)   0           conv2d_1683[0][0]
# __________________________________________________________________________________________________
# conv2d_1684 (Conv2D)            (None, 73, 73, 96)   55392       conv2d_1683[0][0]
# __________________________________________________________________________________________________
# concatenate_314 (Concatenate)   (None, 73, 73, 160)  0           max_pooling2d_94[0][0]
#                                                                  conv2d_1684[0][0]
# __________________________________________________________________________________________________
# conv2d_1687 (Conv2D)            (None, 73, 73, 64)   10304       concatenate_314[0][0]
# __________________________________________________________________________________________________
# conv2d_1688 (Conv2D)            (None, 73, 73, 64)   28736       conv2d_1687[0][0]
# __________________________________________________________________________________________________
# conv2d_1685 (Conv2D)            (None, 73, 73, 64)   10304       concatenate_314[0][0]
# __________________________________________________________________________________________________
# conv2d_1689 (Conv2D)            (None, 73, 73, 64)   28736       conv2d_1688[0][0]
# __________________________________________________________________________________________________
# conv2d_1686 (Conv2D)            (None, 71, 71, 96)   55392       conv2d_1685[0][0]
# __________________________________________________________________________________________________
# conv2d_1690 (Conv2D)            (None, 71, 71, 96)   55392       conv2d_1689[0][0]
# __________________________________________________________________________________________________
# concatenate_315 (Concatenate)   (None, 71, 71, 192)  0           conv2d_1686[0][0]
#                                                                  conv2d_1690[0][0]
# __________________________________________________________________________________________________
# conv2d_1691 (Conv2D)            (None, 35, 35, 192)  331968      concatenate_315[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_95 (MaxPooling2D) (None, 35, 35, 192)  0           concatenate_315[0][0]
# __________________________________________________________________________________________________
# concatenate_316 (Concatenate)   (None, 35, 35, 384)  0           conv2d_1691[0][0]
#                                                                  max_pooling2d_95[0][0]
# __________________________________________________________________________________________________
# conv2d_1695 (Conv2D)            (None, 35, 35, 32)   12320       concatenate_316[0][0]
# __________________________________________________________________________________________________
# conv2d_1693 (Conv2D)            (None, 35, 35, 32)   12320       concatenate_316[0][0]
# __________________________________________________________________________________________________
# conv2d_1696 (Conv2D)            (None, 35, 35, 48)   13872       conv2d_1695[0][0]
# __________________________________________________________________________________________________
# conv2d_1692 (Conv2D)            (None, 35, 35, 32)   12320       concatenate_316[0][0]
# __________________________________________________________________________________________________
# conv2d_1694 (Conv2D)            (None, 35, 35, 32)   9248        conv2d_1693[0][0]
# __________________________________________________________________________________________________
# conv2d_1697 (Conv2D)            (None, 35, 35, 64)   27712       conv2d_1696[0][0]
# __________________________________________________________________________________________________
# concatenate_317 (Concatenate)   (None, 35, 35, 128)  0           conv2d_1692[0][0]
#                                                                  conv2d_1694[0][0]
#                                                                  conv2d_1697[0][0]
# __________________________________________________________________________________________________
# conv2d_1698 (Conv2D)            (None, 35, 35, 384)  49536       concatenate_317[0][0]
# __________________________________________________________________________________________________
# lambda_146 (Lambda)             (None, 35, 35, 384)  0           concatenate_316[0][0]
#                                                                  conv2d_1698[0][0]
# __________________________________________________________________________________________________
# activation_160 (Activation)     (None, 35, 35, 384)  0           lambda_146[0][0]
# __________________________________________________________________________________________________
# conv2d_1702 (Conv2D)            (None, 35, 35, 32)   12320       activation_160[0][0]
# __________________________________________________________________________________________________
# conv2d_1700 (Conv2D)            (None, 35, 35, 32)   12320       activation_160[0][0]
# __________________________________________________________________________________________________
# conv2d_1703 (Conv2D)            (None, 35, 35, 48)   13872       conv2d_1702[0][0]
# __________________________________________________________________________________________________
# conv2d_1699 (Conv2D)            (None, 35, 35, 32)   12320       activation_160[0][0]
# __________________________________________________________________________________________________
# conv2d_1701 (Conv2D)            (None, 35, 35, 32)   9248        conv2d_1700[0][0]
# __________________________________________________________________________________________________
# conv2d_1704 (Conv2D)            (None, 35, 35, 64)   27712       conv2d_1703[0][0]
# __________________________________________________________________________________________________
# concatenate_318 (Concatenate)   (None, 35, 35, 128)  0           conv2d_1699[0][0]
#                                                                  conv2d_1701[0][0]
#                                                                  conv2d_1704[0][0]
# __________________________________________________________________________________________________
# conv2d_1705 (Conv2D)            (None, 35, 35, 384)  49536       concatenate_318[0][0]
# __________________________________________________________________________________________________
# lambda_147 (Lambda)             (None, 35, 35, 384)  0           activation_160[0][0]
#                                                                  conv2d_1705[0][0]
# __________________________________________________________________________________________________
# activation_161 (Activation)     (None, 35, 35, 384)  0           lambda_147[0][0]
# __________________________________________________________________________________________________
# conv2d_1709 (Conv2D)            (None, 35, 35, 32)   12320       activation_161[0][0]
# __________________________________________________________________________________________________
# conv2d_1707 (Conv2D)            (None, 35, 35, 32)   12320       activation_161[0][0]
# __________________________________________________________________________________________________
# conv2d_1710 (Conv2D)            (None, 35, 35, 48)   13872       conv2d_1709[0][0]
# __________________________________________________________________________________________________
# conv2d_1706 (Conv2D)            (None, 35, 35, 32)   12320       activation_161[0][0]
# __________________________________________________________________________________________________
# conv2d_1708 (Conv2D)            (None, 35, 35, 32)   9248        conv2d_1707[0][0]
# __________________________________________________________________________________________________
# conv2d_1711 (Conv2D)            (None, 35, 35, 64)   27712       conv2d_1710[0][0]
# __________________________________________________________________________________________________
# concatenate_319 (Concatenate)   (None, 35, 35, 128)  0           conv2d_1706[0][0]
#                                                                  conv2d_1708[0][0]
#                                                                  conv2d_1711[0][0]
# __________________________________________________________________________________________________
# conv2d_1712 (Conv2D)            (None, 35, 35, 384)  49536       concatenate_319[0][0]
# __________________________________________________________________________________________________
# lambda_148 (Lambda)             (None, 35, 35, 384)  0           activation_161[0][0]
#                                                                  conv2d_1712[0][0]
# __________________________________________________________________________________________________
# activation_162 (Activation)     (None, 35, 35, 384)  0           lambda_148[0][0]
# __________________________________________________________________________________________________
# conv2d_1716 (Conv2D)            (None, 35, 35, 32)   12320       activation_162[0][0]
# __________________________________________________________________________________________________
# conv2d_1714 (Conv2D)            (None, 35, 35, 32)   12320       activation_162[0][0]
# __________________________________________________________________________________________________
# conv2d_1717 (Conv2D)            (None, 35, 35, 48)   13872       conv2d_1716[0][0]
# __________________________________________________________________________________________________
# conv2d_1713 (Conv2D)            (None, 35, 35, 32)   12320       activation_162[0][0]
# __________________________________________________________________________________________________
# conv2d_1715 (Conv2D)            (None, 35, 35, 32)   9248        conv2d_1714[0][0]
# __________________________________________________________________________________________________
# conv2d_1718 (Conv2D)            (None, 35, 35, 64)   27712       conv2d_1717[0][0]
# __________________________________________________________________________________________________
# concatenate_320 (Concatenate)   (None, 35, 35, 128)  0           conv2d_1713[0][0]
#                                                                  conv2d_1715[0][0]
#                                                                  conv2d_1718[0][0]
# __________________________________________________________________________________________________
# conv2d_1719 (Conv2D)            (None, 35, 35, 384)  49536       concatenate_320[0][0]
# __________________________________________________________________________________________________
# lambda_149 (Lambda)             (None, 35, 35, 384)  0           activation_162[0][0]
#                                                                  conv2d_1719[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 35, 35, 384)  0           lambda_149[0][0]
# __________________________________________________________________________________________________
# conv2d_1723 (Conv2D)            (None, 35, 35, 32)   12320       activation_163[0][0]
# __________________________________________________________________________________________________
# conv2d_1721 (Conv2D)            (None, 35, 35, 32)   12320       activation_163[0][0]
# __________________________________________________________________________________________________
# conv2d_1724 (Conv2D)            (None, 35, 35, 48)   13872       conv2d_1723[0][0]
# __________________________________________________________________________________________________
# conv2d_1720 (Conv2D)            (None, 35, 35, 32)   12320       activation_163[0][0]
# __________________________________________________________________________________________________
# conv2d_1722 (Conv2D)            (None, 35, 35, 32)   9248        conv2d_1721[0][0]
# __________________________________________________________________________________________________
# conv2d_1725 (Conv2D)            (None, 35, 35, 64)   27712       conv2d_1724[0][0]
# __________________________________________________________________________________________________
# concatenate_321 (Concatenate)   (None, 35, 35, 128)  0           conv2d_1720[0][0]
#                                                                  conv2d_1722[0][0]
#                                                                  conv2d_1725[0][0]
# __________________________________________________________________________________________________
# conv2d_1726 (Conv2D)            (None, 35, 35, 384)  49536       concatenate_321[0][0]
# __________________________________________________________________________________________________
# lambda_150 (Lambda)             (None, 35, 35, 384)  0           activation_163[0][0]
#                                                                  conv2d_1726[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 35, 35, 384)  0           lambda_150[0][0]
# __________________________________________________________________________________________________
# conv2d_1728 (Conv2D)            (None, 35, 35, 256)  98560       activation_164[0][0]
# __________________________________________________________________________________________________
# conv2d_1729 (Conv2D)            (None, 35, 35, 256)  590080      conv2d_1728[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_96 (MaxPooling2D) (None, 17, 17, 384)  0           activation_164[0][0]
# __________________________________________________________________________________________________
# conv2d_1727 (Conv2D)            (None, 17, 17, 384)  1327488     activation_164[0][0]
# __________________________________________________________________________________________________
# conv2d_1730 (Conv2D)            (None, 17, 17, 384)  885120      conv2d_1729[0][0]
# __________________________________________________________________________________________________
# concatenate_322 (Concatenate)   (None, 17, 17, 1152) 0           max_pooling2d_96[0][0]
#                                                                  conv2d_1727[0][0]
#                                                                  conv2d_1730[0][0]
# __________________________________________________________________________________________________
# conv2d_1732 (Conv2D)            (None, 17, 17, 128)  147584      concatenate_322[0][0]
# __________________________________________________________________________________________________
# conv2d_1733 (Conv2D)            (None, 17, 17, 160)  143520      conv2d_1732[0][0]
# __________________________________________________________________________________________________
# conv2d_1731 (Conv2D)            (None, 17, 17, 192)  221376      concatenate_322[0][0]
# __________________________________________________________________________________________________
# conv2d_1734 (Conv2D)            (None, 17, 17, 192)  215232      conv2d_1733[0][0]
# __________________________________________________________________________________________________
# concatenate_323 (Concatenate)   (None, 17, 17, 384)  0           conv2d_1731[0][0]
#                                                                  conv2d_1734[0][0]
# __________________________________________________________________________________________________
# conv2d_1735 (Conv2D)            (None, 17, 17, 1152) 443520      concatenate_323[0][0]
# __________________________________________________________________________________________________
# lambda_151 (Lambda)             (None, 17, 17, 1152) 0           concatenate_322[0][0]
#                                                                  conv2d_1735[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 17, 17, 1152) 0           lambda_151[0][0]
# __________________________________________________________________________________________________
# conv2d_1737 (Conv2D)            (None, 17, 17, 128)  147584      activation_165[0][0]
# __________________________________________________________________________________________________
# conv2d_1738 (Conv2D)            (None, 17, 17, 160)  143520      conv2d_1737[0][0]
# __________________________________________________________________________________________________
# conv2d_1736 (Conv2D)            (None, 17, 17, 192)  221376      activation_165[0][0]
# __________________________________________________________________________________________________
# conv2d_1739 (Conv2D)            (None, 17, 17, 192)  215232      conv2d_1738[0][0]
# __________________________________________________________________________________________________
# concatenate_324 (Concatenate)   (None, 17, 17, 384)  0           conv2d_1736[0][0]
#                                                                  conv2d_1739[0][0]
# __________________________________________________________________________________________________
# conv2d_1740 (Conv2D)            (None, 17, 17, 1152) 443520      concatenate_324[0][0]
# __________________________________________________________________________________________________
# lambda_152 (Lambda)             (None, 17, 17, 1152) 0           activation_165[0][0]
#                                                                  conv2d_1740[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 17, 17, 1152) 0           lambda_152[0][0]
# __________________________________________________________________________________________________
# conv2d_1742 (Conv2D)            (None, 17, 17, 128)  147584      activation_166[0][0]
# __________________________________________________________________________________________________
# conv2d_1743 (Conv2D)            (None, 17, 17, 160)  143520      conv2d_1742[0][0]
# __________________________________________________________________________________________________
# conv2d_1741 (Conv2D)            (None, 17, 17, 192)  221376      activation_166[0][0]
# __________________________________________________________________________________________________
# conv2d_1744 (Conv2D)            (None, 17, 17, 192)  215232      conv2d_1743[0][0]
# __________________________________________________________________________________________________
# concatenate_325 (Concatenate)   (None, 17, 17, 384)  0           conv2d_1741[0][0]
#                                                                  conv2d_1744[0][0]
# __________________________________________________________________________________________________
# conv2d_1745 (Conv2D)            (None, 17, 17, 1152) 443520      concatenate_325[0][0]
# __________________________________________________________________________________________________
# lambda_153 (Lambda)             (None, 17, 17, 1152) 0           activation_166[0][0]
#                                                                  conv2d_1745[0][0]
# __________________________________________________________________________________________________
# activation_167 (Activation)     (None, 17, 17, 1152) 0           lambda_153[0][0]
# __________________________________________________________________________________________________
# conv2d_1747 (Conv2D)            (None, 17, 17, 128)  147584      activation_167[0][0]
# __________________________________________________________________________________________________
# conv2d_1748 (Conv2D)            (None, 17, 17, 160)  143520      conv2d_1747[0][0]
# __________________________________________________________________________________________________
# conv2d_1746 (Conv2D)            (None, 17, 17, 192)  221376      activation_167[0][0]
# __________________________________________________________________________________________________
# conv2d_1749 (Conv2D)            (None, 17, 17, 192)  215232      conv2d_1748[0][0]
# __________________________________________________________________________________________________
# concatenate_326 (Concatenate)   (None, 17, 17, 384)  0           conv2d_1746[0][0]
#                                                                  conv2d_1749[0][0]
# __________________________________________________________________________________________________
# conv2d_1750 (Conv2D)            (None, 17, 17, 1152) 443520      concatenate_326[0][0]
# __________________________________________________________________________________________________
# lambda_154 (Lambda)             (None, 17, 17, 1152) 0           activation_167[0][0]
#                                                                  conv2d_1750[0][0]
# __________________________________________________________________________________________________
# activation_168 (Activation)     (None, 17, 17, 1152) 0           lambda_154[0][0]
# __________________________________________________________________________________________________
# conv2d_1752 (Conv2D)            (None, 17, 17, 128)  147584      activation_168[0][0]
# __________________________________________________________________________________________________
# conv2d_1753 (Conv2D)            (None, 17, 17, 160)  143520      conv2d_1752[0][0]
# __________________________________________________________________________________________________
# conv2d_1751 (Conv2D)            (None, 17, 17, 192)  221376      activation_168[0][0]
# __________________________________________________________________________________________________
# conv2d_1754 (Conv2D)            (None, 17, 17, 192)  215232      conv2d_1753[0][0]
# __________________________________________________________________________________________________
# concatenate_327 (Concatenate)   (None, 17, 17, 384)  0           conv2d_1751[0][0]
#                                                                  conv2d_1754[0][0]
# __________________________________________________________________________________________________
# conv2d_1755 (Conv2D)            (None, 17, 17, 1152) 443520      concatenate_327[0][0]
# __________________________________________________________________________________________________
# lambda_155 (Lambda)             (None, 17, 17, 1152) 0           activation_168[0][0]
#                                                                  conv2d_1755[0][0]
# __________________________________________________________________________________________________
# activation_169 (Activation)     (None, 17, 17, 1152) 0           lambda_155[0][0]
# __________________________________________________________________________________________________
# conv2d_1757 (Conv2D)            (None, 17, 17, 128)  147584      activation_169[0][0]
# __________________________________________________________________________________________________
# conv2d_1758 (Conv2D)            (None, 17, 17, 160)  143520      conv2d_1757[0][0]
# __________________________________________________________________________________________________
# conv2d_1756 (Conv2D)            (None, 17, 17, 192)  221376      activation_169[0][0]
# __________________________________________________________________________________________________
# conv2d_1759 (Conv2D)            (None, 17, 17, 192)  215232      conv2d_1758[0][0]
# __________________________________________________________________________________________________
# concatenate_328 (Concatenate)   (None, 17, 17, 384)  0           conv2d_1756[0][0]
#                                                                  conv2d_1759[0][0]
# __________________________________________________________________________________________________
# conv2d_1760 (Conv2D)            (None, 17, 17, 1152) 443520      concatenate_328[0][0]
# __________________________________________________________________________________________________
# lambda_156 (Lambda)             (None, 17, 17, 1152) 0           activation_169[0][0]
#                                                                  conv2d_1760[0][0]
# __________________________________________________________________________________________________
# activation_170 (Activation)     (None, 17, 17, 1152) 0           lambda_156[0][0]
# __________________________________________________________________________________________________
# conv2d_1762 (Conv2D)            (None, 17, 17, 128)  147584      activation_170[0][0]
# __________________________________________________________________________________________________
# conv2d_1763 (Conv2D)            (None, 17, 17, 160)  143520      conv2d_1762[0][0]
# __________________________________________________________________________________________________
# conv2d_1761 (Conv2D)            (None, 17, 17, 192)  221376      activation_170[0][0]
# __________________________________________________________________________________________________
# conv2d_1764 (Conv2D)            (None, 17, 17, 192)  215232      conv2d_1763[0][0]
# __________________________________________________________________________________________________
# concatenate_329 (Concatenate)   (None, 17, 17, 384)  0           conv2d_1761[0][0]
#                                                                  conv2d_1764[0][0]
# __________________________________________________________________________________________________
# conv2d_1765 (Conv2D)            (None, 17, 17, 1152) 443520      concatenate_329[0][0]
# __________________________________________________________________________________________________
# lambda_157 (Lambda)             (None, 17, 17, 1152) 0           activation_170[0][0]
#                                                                  conv2d_1765[0][0]
# __________________________________________________________________________________________________
# activation_171 (Activation)     (None, 17, 17, 1152) 0           lambda_157[0][0]
# __________________________________________________________________________________________________
# conv2d_1767 (Conv2D)            (None, 17, 17, 128)  147584      activation_171[0][0]
# __________________________________________________________________________________________________
# conv2d_1768 (Conv2D)            (None, 17, 17, 160)  143520      conv2d_1767[0][0]
# __________________________________________________________________________________________________
# conv2d_1766 (Conv2D)            (None, 17, 17, 192)  221376      activation_171[0][0]
# __________________________________________________________________________________________________
# conv2d_1769 (Conv2D)            (None, 17, 17, 192)  215232      conv2d_1768[0][0]
# __________________________________________________________________________________________________
# concatenate_330 (Concatenate)   (None, 17, 17, 384)  0           conv2d_1766[0][0]
#                                                                  conv2d_1769[0][0]
# __________________________________________________________________________________________________
# conv2d_1770 (Conv2D)            (None, 17, 17, 1152) 443520      concatenate_330[0][0]
# __________________________________________________________________________________________________
# lambda_158 (Lambda)             (None, 17, 17, 1152) 0           activation_171[0][0]
#                                                                  conv2d_1770[0][0]
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, 17, 17, 1152) 0           lambda_158[0][0]
# __________________________________________________________________________________________________
# conv2d_1772 (Conv2D)            (None, 17, 17, 128)  147584      activation_172[0][0]
# __________________________________________________________________________________________________
# conv2d_1773 (Conv2D)            (None, 17, 17, 160)  143520      conv2d_1772[0][0]
# __________________________________________________________________________________________________
# conv2d_1771 (Conv2D)            (None, 17, 17, 192)  221376      activation_172[0][0]
# __________________________________________________________________________________________________
# conv2d_1774 (Conv2D)            (None, 17, 17, 192)  215232      conv2d_1773[0][0]
# __________________________________________________________________________________________________
# concatenate_331 (Concatenate)   (None, 17, 17, 384)  0           conv2d_1771[0][0]
#                                                                  conv2d_1774[0][0]
# __________________________________________________________________________________________________
# conv2d_1775 (Conv2D)            (None, 17, 17, 1152) 443520      concatenate_331[0][0]
# __________________________________________________________________________________________________
# lambda_159 (Lambda)             (None, 17, 17, 1152) 0           activation_172[0][0]
#                                                                  conv2d_1775[0][0]
# __________________________________________________________________________________________________
# activation_173 (Activation)     (None, 17, 17, 1152) 0           lambda_159[0][0]
# __________________________________________________________________________________________________
# conv2d_1777 (Conv2D)            (None, 17, 17, 128)  147584      activation_173[0][0]
# __________________________________________________________________________________________________
# conv2d_1778 (Conv2D)            (None, 17, 17, 160)  143520      conv2d_1777[0][0]
# __________________________________________________________________________________________________
# conv2d_1776 (Conv2D)            (None, 17, 17, 192)  221376      activation_173[0][0]
# __________________________________________________________________________________________________
# conv2d_1779 (Conv2D)            (None, 17, 17, 192)  215232      conv2d_1778[0][0]
# __________________________________________________________________________________________________
# concatenate_332 (Concatenate)   (None, 17, 17, 384)  0           conv2d_1776[0][0]
#                                                                  conv2d_1779[0][0]
# __________________________________________________________________________________________________
# conv2d_1780 (Conv2D)            (None, 17, 17, 1152) 443520      concatenate_332[0][0]
# __________________________________________________________________________________________________
# lambda_160 (Lambda)             (None, 17, 17, 1152) 0           activation_173[0][0]
#                                                                  conv2d_1780[0][0]
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 17, 17, 1152) 0           lambda_160[0][0]
# __________________________________________________________________________________________________
# conv2d_1785 (Conv2D)            (None, 17, 17, 256)  295168      activation_174[0][0]
# __________________________________________________________________________________________________
# conv2d_1781 (Conv2D)            (None, 17, 17, 256)  295168      activation_174[0][0]
# __________________________________________________________________________________________________
# conv2d_1783 (Conv2D)            (None, 17, 17, 256)  295168      activation_174[0][0]
# __________________________________________________________________________________________________
# conv2d_1786 (Conv2D)            (None, 17, 17, 256)  590080      conv2d_1785[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_97 (MaxPooling2D) (None, 8, 8, 1152)   0           activation_174[0][0]
# __________________________________________________________________________________________________
# conv2d_1782 (Conv2D)            (None, 8, 8, 384)    885120      conv2d_1781[0][0]
# __________________________________________________________________________________________________
# conv2d_1784 (Conv2D)            (None, 8, 8, 256)    590080      conv2d_1783[0][0]
# __________________________________________________________________________________________________
# conv2d_1787 (Conv2D)            (None, 8, 8, 256)    590080      conv2d_1786[0][0]
# __________________________________________________________________________________________________
# concatenate_333 (Concatenate)   (None, 8, 8, 2048)   0           max_pooling2d_97[0][0]
#                                                                  conv2d_1782[0][0]
#                                                                  conv2d_1784[0][0]
#                                                                  conv2d_1787[0][0]
# __________________________________________________________________________________________________
# conv2d_1789 (Conv2D)            (None, 8, 8, 192)    393408      concatenate_333[0][0]
# __________________________________________________________________________________________________
# conv2d_1790 (Conv2D)            (None, 8, 8, 224)    129248      conv2d_1789[0][0]
# __________________________________________________________________________________________________
# conv2d_1788 (Conv2D)            (None, 8, 8, 192)    393408      concatenate_333[0][0]
# __________________________________________________________________________________________________
# conv2d_1791 (Conv2D)            (None, 8, 8, 256)    172288      conv2d_1790[0][0]
# __________________________________________________________________________________________________
# concatenate_334 (Concatenate)   (None, 8, 8, 448)    0           conv2d_1788[0][0]
#                                                                  conv2d_1791[0][0]
# __________________________________________________________________________________________________
# conv2d_1792 (Conv2D)            (None, 8, 8, 2048)   919552      concatenate_334[0][0]
# __________________________________________________________________________________________________
# lambda_161 (Lambda)             (None, 8, 8, 2048)   0           concatenate_333[0][0]
#                                                                  conv2d_1792[0][0]
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, 8, 8, 2048)   0           lambda_161[0][0]
# __________________________________________________________________________________________________
# conv2d_1794 (Conv2D)            (None, 8, 8, 192)    393408      activation_175[0][0]
# __________________________________________________________________________________________________
# conv2d_1795 (Conv2D)            (None, 8, 8, 224)    129248      conv2d_1794[0][0]
# __________________________________________________________________________________________________
# conv2d_1793 (Conv2D)            (None, 8, 8, 192)    393408      activation_175[0][0]
# __________________________________________________________________________________________________
# conv2d_1796 (Conv2D)            (None, 8, 8, 256)    172288      conv2d_1795[0][0]
# __________________________________________________________________________________________________
# concatenate_335 (Concatenate)   (None, 8, 8, 448)    0           conv2d_1793[0][0]
#                                                                  conv2d_1796[0][0]
# __________________________________________________________________________________________________
# conv2d_1797 (Conv2D)            (None, 8, 8, 2048)   919552      concatenate_335[0][0]
# __________________________________________________________________________________________________
# lambda_162 (Lambda)             (None, 8, 8, 2048)   0           activation_175[0][0]
#                                                                  conv2d_1797[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 8, 8, 2048)   0           lambda_162[0][0]
# __________________________________________________________________________________________________
# conv2d_1799 (Conv2D)            (None, 8, 8, 192)    393408      activation_176[0][0]
# __________________________________________________________________________________________________
# conv2d_1800 (Conv2D)            (None, 8, 8, 224)    129248      conv2d_1799[0][0]
# __________________________________________________________________________________________________
# conv2d_1798 (Conv2D)            (None, 8, 8, 192)    393408      activation_176[0][0]
# __________________________________________________________________________________________________
# conv2d_1801 (Conv2D)            (None, 8, 8, 256)    172288      conv2d_1800[0][0]
# __________________________________________________________________________________________________
# concatenate_336 (Concatenate)   (None, 8, 8, 448)    0           conv2d_1798[0][0]
#                                                                  conv2d_1801[0][0]
# __________________________________________________________________________________________________
# conv2d_1802 (Conv2D)            (None, 8, 8, 2048)   919552      concatenate_336[0][0]
# __________________________________________________________________________________________________
# lambda_163 (Lambda)             (None, 8, 8, 2048)   0           activation_176[0][0]
#                                                                  conv2d_1802[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 8, 8, 2048)   0           lambda_163[0][0]
# __________________________________________________________________________________________________
# conv2d_1804 (Conv2D)            (None, 8, 8, 192)    393408      activation_177[0][0]
# __________________________________________________________________________________________________
# conv2d_1805 (Conv2D)            (None, 8, 8, 224)    129248      conv2d_1804[0][0]
# __________________________________________________________________________________________________
# conv2d_1803 (Conv2D)            (None, 8, 8, 192)    393408      activation_177[0][0]
# __________________________________________________________________________________________________
# conv2d_1806 (Conv2D)            (None, 8, 8, 256)    172288      conv2d_1805[0][0]
# __________________________________________________________________________________________________
# concatenate_337 (Concatenate)   (None, 8, 8, 448)    0           conv2d_1803[0][0]
#                                                                  conv2d_1806[0][0]
# __________________________________________________________________________________________________
# conv2d_1807 (Conv2D)            (None, 8, 8, 2048)   919552      concatenate_337[0][0]
# __________________________________________________________________________________________________
# lambda_164 (Lambda)             (None, 8, 8, 2048)   0           activation_177[0][0]
#                                                                  conv2d_1807[0][0]
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 8, 8, 2048)   0           lambda_164[0][0]
# __________________________________________________________________________________________________
# conv2d_1809 (Conv2D)            (None, 8, 8, 192)    393408      activation_178[0][0]
# __________________________________________________________________________________________________
# conv2d_1810 (Conv2D)            (None, 8, 8, 224)    129248      conv2d_1809[0][0]
# __________________________________________________________________________________________________
# conv2d_1808 (Conv2D)            (None, 8, 8, 192)    393408      activation_178[0][0]
# __________________________________________________________________________________________________
# conv2d_1811 (Conv2D)            (None, 8, 8, 256)    172288      conv2d_1810[0][0]
# __________________________________________________________________________________________________
# concatenate_338 (Concatenate)   (None, 8, 8, 448)    0           conv2d_1808[0][0]
#                                                                  conv2d_1811[0][0]
# __________________________________________________________________________________________________
# conv2d_1812 (Conv2D)            (None, 8, 8, 2048)   919552      concatenate_338[0][0]
# __________________________________________________________________________________________________
# lambda_165 (Lambda)             (None, 8, 8, 2048)   0           activation_178[0][0]
#                                                                  conv2d_1812[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 8, 8, 2048)   0           lambda_165[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 4, 4, 2048)   0           activation_179[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 32768)        0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1792)         58722048    flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1792)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1000)         1793000     dropout_1[0][0]
# ==================================================================================================
# Total params: 90,000,504
# Trainable params: 90,000,504
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, 
           to_file='model.pdf', 
           show_shapes=True, 
           show_layer_names=False,
           rankdir='TB')
