# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import urllib.request
import re

# f = open("Flower images · Pexels · Free Stock Photos.html","r", encoding="utf8")
# f = open("250+ Amazing Umbrella Photos · Pexels · Free Stock Photos.html","r", encoding="utf8")
# f1 = f.readlines()
# list = []
# for x in f1:
#     if x.find('srcset=') > 0 and x.find('.jpg') > x.find('srcset='):
#         url = x[x.find('srcset=')+8:x.find('.jpg')+4]
#         if len(url) < 200:
#             print(url)
#             list.append(url)
#     elif x.find('srcset=') > 0 and x.find('.jpeg') > x.find('srcset='):
#         url = x[x.find('srcset=')+8:x.find('.jpeg')+5]
#         if len(url) < 200:
#             print(url)
#             list.append(url)
# print(len(list))
# f.close()

text_file = "Pexels-Flowers.txt"
# text_file = "Pexels-Umbrellas.txt"
url_list = []
with open(text_file) as f:
    lines = f.readlines()
list = [img_url.rstrip('\n') for img_url in lines]

for i in range(len(list)):
    url_list.append(list[i])
    print(list[i])
print(len(url_list))
# Out:
# https://images.pexels.com/photos/67636/rose-blue-flower-rose-blooms-67636.jpeg
# https://images.pexels.com/photos/1115090/pexels-photo-1115090.jpeg
# https://images.pexels.com/photos/36764/marguerite-daisy-beautiful-beauty.jpg
# https://images.pexels.com/photos/1040626/pexels-photo-1040626.jpeg
# https://images.pexels.com/photos/1070860/pexels-photo-1070860.jpeg
# https://images.pexels.com/photos/1058771/pexels-photo-1058771.jpeg
# https://images.pexels.com/photos/1083822/pexels-photo-1083822.jpeg
# https://images.pexels.com/photos/133472/pexels-photo-133472.jpeg
# https://images.pexels.com/photos/1212487/pexels-photo-1212487.jpeg
# https://images.pexels.com/photos/192544/dandelion-sun-dew-water-192544.jpeg
# https://images.pexels.com/photos/1366630/pexels-photo-1366630.jpeg
# https://images.pexels.com/photos/33044/sunflower-sun-summer-yellow.jpg
# https://images.pexels.com/photos/1030845/pexels-photo-1030845.jpeg
# https://images.pexels.com/photos/1803911/pexels-photo-1803911.jpeg
# ...

# %%
import wget
from PIL import Image
import os
import urllib
import glob
import random
import requests

root_name = "./data/pxl_flower_"
# root_name = "./data/pxl_umbrella_"

# %%
user_agents=['Mozilla/5.0 (Windows NT 6.1; WOW64; rv:23.0) Gecko/20130406 Firefox/23.0',
                           'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:18.0) Gecko/20100101 Firefox/18.0',
                           'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US) AppleWebKit/533+ \(KHTML, like Gecko) Element Browser 5.0',
                           'IBM WebExplorer /v0.94', 'Galaxy/1.0 [en] (Mac OS X 10.5.6; U; en)',
                           'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)',
                           'Opera/9.80 (Windows NT 6.0) Presto/2.12.388 Version/12.14',
                           'Mozilla/5.0 (iPad; CPU OS 6_0 like Mac OS X) AppleWebKit/536.26 (KHTML, like Gecko) \Version/6.0 Mobile/10A5355d Safari/8536.25',
                           'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) \Chrome/28.0.1468.0 Safari/537.36',
                           'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.0; Trident/5.0; TheWorld)']

# %%
for i in range(len(url_list)): 
    try:
        url = url_list[i]
        print('Index %s, Downloading image %s' %(i, url))

        index=random.randint(0, 9)
        user_agent=user_agents[index]
        headers={'User_agent':user_agent}
        picture=requests.get(url,headers)
        full_name = root_name + str(i).zfill(5) + ".jpeg"

        f=open(full_name, 'wb')
        f.write(picture.content)
        f.close()
        print("\n")
    except:
            print("Error downloading this image!")

print("Finished Downloading %s images" %(len(lines)))
# Out:
# Index 0, Downloading image https://images.pexels.com/photos/67636/rose-blue-flower-rose-blooms-67636.jpeg
#
#
# Index 1, Downloading image https://images.pexels.com/photos/1115090/pexels-photo-1115090.jpeg
#
#
# Index 2, Downloading image https://images.pexels.com/photos/36764/marguerite-daisy-beautiful-beauty.jpg
#
#
# Index 3, Downloading image https://images.pexels.com/photos/1040626/pexels-photo-1040626.jpeg
#
#
# Index 4, Downloading image https://images.pexels.com/photos/1070860/pexels-photo-1070860.jpeg
#
#
# Index 5, Downloading image https://images.pexels.com/photos/1058771/pexels-photo-1058771.jpeg
#
#
# Index 6, Downloading image https://images.pexels.com/photos/1083822/pexels-photo-1083822.jpeg
#
#
# Index 7, Downloading image https://images.pexels.com/photos/133472/pexels-photo-133472.jpeg
#
#
# Index 8, Downloading image https://images.pexels.com/photos/1212487/pexels-photo-1212487.jpeg
#
#
# ...
