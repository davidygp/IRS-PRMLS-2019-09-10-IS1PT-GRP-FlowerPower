# %%
import glob
import math
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import random
import sklearn.metrics as metrics

from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, LearningRateScheduler
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import add, concatenate, Conv2D, Dense, Dropout, Flatten, Input
from tensorflow.keras.layers import Activation, AveragePooling2D, BatchNormalization, MaxPooling2D
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical


# %matplotlib inline

# %%
imgrows=299
imgclms=299
channel=3

def stem_block(inputs,
         names=None):
    x = inputs
    
    x = Conv2D(filters=32, kernel_size=(3, 3), strides=2, padding='valid')(inputs)
    x = Conv2D(filters=32, kernel_size=(3, 3), strides=1, padding='valid')(x)
    x = Conv2D(filters=64, kernel_size=(3, 3), strides=1, padding='same')(x)
    x_L1_1 = MaxPooling2D(pool_size=(3, 3), strides=2, padding='valid')(x)
    x_R1_1 = Conv2D(filters=96, kernel_size=(3, 3), strides=2, padding='valid')(x)
    x = concatenate([x_L1_1, x_R1_1])
    
    x_L2_1 = Conv2D(filters=64, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_L2_2 = Conv2D(filters=96, kernel_size=(3, 3), strides=1, padding='valid')(x_L2_1)
    x_R2_1 = Conv2D(filters=64, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_R2_2 = Conv2D(filters=64, kernel_size=(7, 1), strides=1, padding='same')(x_R2_1)
    x_R2_3 = Conv2D(filters=64, kernel_size=(1, 7), strides=1, padding='same')(x_R2_2)
    x_R2_4 = Conv2D(filters=96, kernel_size=(3, 3), strides=1, padding='valid')(x_R2_3)
    x = concatenate([x_L2_2, x_R2_4])
    
    x_L3_1 = Conv2D(filters=192, kernel_size=(3, 3), strides=2, padding='valid')(x)
    x_R3_1 = MaxPooling2D(strides=2, padding='valid')(x)
    x = concatenate([x_L3_1, x_R3_1])
    return x

def inception_a_block(inputs,
         names=None):
    x = inputs
    
    x_EL1_1 = AveragePooling2D(pool_size=(1, 1), padding='same')(x)
    x_EL1_2 = Conv2D(filters=96, kernel_size=(1, 1), strides=1, padding='same')(x_EL1_1)
    
    x_ML1_1 = Conv2D(filters=96, kernel_size=(1, 1), strides=1, padding='same')(x)
    
    x_MR1_1 = Conv2D(filters=64, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_MR1_2 = Conv2D(filters=96, kernel_size=(3, 3), strides=1, padding='same')(x_MR1_1)
    
    x_ER1_1 = Conv2D(filters=64, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_ER1_2 = Conv2D(filters=96, kernel_size=(3, 3), strides=1, padding='same')(x_ER1_1)
    x_ER1_3 = Conv2D(filters=96, kernel_size=(3, 3), strides=1, padding='same')(x_ER1_2)
    
    x = concatenate([x_EL1_2, x_ML1_1, x_MR1_2, x_ER1_3])
    return x

def inception_b_block(inputs,
         names=None):
    x = inputs
    
    x_EL1_1 = AveragePooling2D(pool_size=(1, 1), padding='same')(x)
    x_EL1_2 = Conv2D(filters=128, kernel_size=(1, 1), strides=1, padding='same')(x_EL1_1)
    
    x_ML1_1 = Conv2D(filters=384, kernel_size=(1, 1), strides=1, padding='same')(x)
    
    x_MR1_1 = Conv2D(filters=192, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_MR1_2 = Conv2D(filters=224, kernel_size=(1, 7), strides=1, padding='same')(x_MR1_1)
    x_MR1_3 = Conv2D(filters=256, kernel_size=(1, 7), strides=1, padding='same')(x_MR1_2)
    
    x_ER1_1 = Conv2D(filters=192, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_ER1_2 = Conv2D(filters=192, kernel_size=(1, 7), strides=1, padding='same')(x_ER1_1)
    x_ER1_3 = Conv2D(filters=224, kernel_size=(7, 1), strides=1, padding='same')(x_ER1_2)
    x_ER1_4 = Conv2D(filters=224, kernel_size=(1, 7), strides=1, padding='same')(x_ER1_3)
    x_ER1_5 = Conv2D(filters=256, kernel_size=(7, 1), strides=1, padding='same')(x_ER1_4)

    x = concatenate([x_EL1_2, x_ML1_1, x_MR1_3, x_ER1_5])
    return x

def inception_c_block(inputs,
         names=None):
    x = inputs
    
    x_EL1_1 = AveragePooling2D(pool_size=(1, 1), padding='same')(x)
    x_EL1_2 = Conv2D(filters=256, kernel_size=(1, 1), strides=1, padding='same')(x_EL1_1)
    
    x_ML1_1 = Conv2D(filters=256, kernel_size=(1, 1), strides=1, padding='same')(x)
    
    x_MR1_1 = Conv2D(filters=384, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_MR1_1_L2 = Conv2D(filters=256, kernel_size=(1, 3), strides=1, padding='same')(x_MR1_1)
    x_MR1_1_R2 = Conv2D(filters=256, kernel_size=(3, 1), strides=1, padding='same')(x_MR1_1)
    
    x_ER1_1 = Conv2D(filters=384, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_ER1_2 = Conv2D(filters=448, kernel_size=(1, 3), strides=1, padding='same')(x_ER1_1)
    x_ER1_3 = Conv2D(filters=512, kernel_size=(3, 1), strides=1, padding='same')(x_ER1_2)
    x_ER1_3_L1 = Conv2D(filters=256, kernel_size=(3, 1), strides=1, padding='same')(x_ER1_3)
    x_ER1_3_R1 = Conv2D(filters=256, kernel_size=(1, 3), strides=1, padding='same')(x_ER1_3)
    
    x = concatenate([x_EL1_2, x_ML1_1, x_MR1_1_L2, x_MR1_1_R2, x_ER1_3_L1, x_ER1_3_R1])
    return x

def reduction_a_block(inputs,
                      network_selected="Inception-v4",
                      names=None):
    if network_selected == "Inception-v4":
        k, l, m, n = 192, 224, 256, 384
    elif network_selected == "Inception-ResNet-v1":
        k, l, m, n = 192, 192, 256, 384
    elif network_selected == "Inception-ResNet-v2":
        k, l, m, n = 256, 256, 384, 384
        
    x = inputs
    
    x_L_1 = MaxPooling2D(pool_size=(3, 3), strides=2, padding='valid')(x)
    
    x_M_1 = Conv2D(filters=n, kernel_size=(3, 3), strides=2, padding='valid')(x)
    
    x_R_1 = Conv2D(filters=k, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_R_2 = Conv2D(filters=l, kernel_size=(3, 3), strides=1, padding='same')(x_R_1)
    x_R_3 = Conv2D(filters=m, kernel_size=(3, 3), strides=2, padding='valid')(x_R_2)
    
    x = concatenate([x_L_1, x_M_1, x_R_3])
    return x

def reduction_b_block(inputs,
                      names=None):

        
    x = inputs
    
    x_L_1 = MaxPooling2D(pool_size=(3, 3), strides=2, padding='valid')(x)
    
    x_M_1 = Conv2D(filters=192, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_M_2 = Conv2D(filters=192, kernel_size=(3, 3), strides=2, padding='valid')(x_M_1)
    
    x_R_1 = Conv2D(filters=256, kernel_size=(1, 1), strides=1, padding='same')(x)
    x_R_2 = Conv2D(filters=256, kernel_size=(1, 7), strides=1, padding='same')(x_R_1)
    x_R_3 = Conv2D(filters=320, kernel_size=(7, 1), strides=1, padding='same')(x_R_2)
    x_R_4 = Conv2D(filters=320, kernel_size=(3, 3), strides=2, padding='valid')(x_R_3)
    
    x = concatenate([x_L_1, x_M_2, x_R_4])
    return x

def create_inception_v4(inputShape=(imgrows, imgclms, channel),
                   num_classes=2):
    NETWORK_SELECTED = "Inception-v4"
    inputs = Input(shape=inputShape)
    x = stem_block(inputs)
    x = inception_a_block(x)
    x = inception_a_block(x)
    x = inception_a_block(x)
    x = inception_a_block(x)
    x = reduction_a_block(x, network_selected=NETWORK_SELECTED)
    
    x = inception_b_block(x)
    x = inception_b_block(x)
    x = inception_b_block(x)
    x = inception_b_block(x)
    x = inception_b_block(x)
    x = inception_b_block(x)
    x = inception_b_block(x)
    reduction_b_block(x)
                      
    x = inception_c_block(x)
    x = inception_c_block(x)
    x = inception_c_block(x)
    x = AveragePooling2D()(x)
    x = Flatten()(x)
    x = Dense(1536)(x)
    x = Dropout(0.2)(x)
    outputs = Dense(num_classes, activation='softmax', 
                    kernel_initializer='he_normal')(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(loss='categorical_crossentropy', 
                  optimizer="Adam", 
                  metrics=['accuracy'])
    return model

model = create_inception_v4()
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv2d_721 (Conv2D)             (None, 149, 149, 32) 896         input_6[0][0]
# __________________________________________________________________________________________________
# conv2d_722 (Conv2D)             (None, 147, 147, 32) 9248        conv2d_721[0][0]
# __________________________________________________________________________________________________
# conv2d_723 (Conv2D)             (None, 147, 147, 64) 18496       conv2d_722[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 73, 73, 64)   0           conv2d_723[0][0]
# __________________________________________________________________________________________________
# conv2d_724 (Conv2D)             (None, 73, 73, 96)   55392       conv2d_723[0][0]
# __________________________________________________________________________________________________
# concatenate_91 (Concatenate)    (None, 73, 73, 160)  0           max_pooling2d_16[0][0]
#                                                                  conv2d_724[0][0]
# __________________________________________________________________________________________________
# conv2d_727 (Conv2D)             (None, 73, 73, 64)   10304       concatenate_91[0][0]
# __________________________________________________________________________________________________
# conv2d_728 (Conv2D)             (None, 73, 73, 64)   28736       conv2d_727[0][0]
# __________________________________________________________________________________________________
# conv2d_725 (Conv2D)             (None, 73, 73, 64)   10304       concatenate_91[0][0]
# __________________________________________________________________________________________________
# conv2d_729 (Conv2D)             (None, 73, 73, 64)   28736       conv2d_728[0][0]
# __________________________________________________________________________________________________
# conv2d_726 (Conv2D)             (None, 71, 71, 96)   55392       conv2d_725[0][0]
# __________________________________________________________________________________________________
# conv2d_730 (Conv2D)             (None, 71, 71, 96)   55392       conv2d_729[0][0]
# __________________________________________________________________________________________________
# concatenate_92 (Concatenate)    (None, 71, 71, 192)  0           conv2d_726[0][0]
#                                                                  conv2d_730[0][0]
# __________________________________________________________________________________________________
# conv2d_731 (Conv2D)             (None, 35, 35, 192)  331968      concatenate_92[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 35, 35, 192)  0           concatenate_92[0][0]
# __________________________________________________________________________________________________
# concatenate_93 (Concatenate)    (None, 35, 35, 384)  0           conv2d_731[0][0]
#                                                                  max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_736 (Conv2D)             (None, 35, 35, 64)   24640       concatenate_93[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_74 (AveragePo (None, 35, 35, 384)  0           concatenate_93[0][0]
# __________________________________________________________________________________________________
# conv2d_734 (Conv2D)             (None, 35, 35, 64)   24640       concatenate_93[0][0]
# __________________________________________________________________________________________________
# conv2d_737 (Conv2D)             (None, 35, 35, 96)   55392       conv2d_736[0][0]
# __________________________________________________________________________________________________
# conv2d_732 (Conv2D)             (None, 35, 35, 96)   36960       average_pooling2d_74[0][0]
# __________________________________________________________________________________________________
# conv2d_733 (Conv2D)             (None, 35, 35, 96)   36960       concatenate_93[0][0]
# __________________________________________________________________________________________________
# conv2d_735 (Conv2D)             (None, 35, 35, 96)   55392       conv2d_734[0][0]
# __________________________________________________________________________________________________
# conv2d_738 (Conv2D)             (None, 35, 35, 96)   83040       conv2d_737[0][0]
# __________________________________________________________________________________________________
# concatenate_94 (Concatenate)    (None, 35, 35, 384)  0           conv2d_732[0][0]
#                                                                  conv2d_733[0][0]
#                                                                  conv2d_735[0][0]
#                                                                  conv2d_738[0][0]
# __________________________________________________________________________________________________
# conv2d_743 (Conv2D)             (None, 35, 35, 64)   24640       concatenate_94[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_75 (AveragePo (None, 35, 35, 384)  0           concatenate_94[0][0]
# __________________________________________________________________________________________________
# conv2d_741 (Conv2D)             (None, 35, 35, 64)   24640       concatenate_94[0][0]
# __________________________________________________________________________________________________
# conv2d_744 (Conv2D)             (None, 35, 35, 96)   55392       conv2d_743[0][0]
# __________________________________________________________________________________________________
# conv2d_739 (Conv2D)             (None, 35, 35, 96)   36960       average_pooling2d_75[0][0]
# __________________________________________________________________________________________________
# conv2d_740 (Conv2D)             (None, 35, 35, 96)   36960       concatenate_94[0][0]
# __________________________________________________________________________________________________
# conv2d_742 (Conv2D)             (None, 35, 35, 96)   55392       conv2d_741[0][0]
# __________________________________________________________________________________________________
# conv2d_745 (Conv2D)             (None, 35, 35, 96)   83040       conv2d_744[0][0]
# __________________________________________________________________________________________________
# concatenate_95 (Concatenate)    (None, 35, 35, 384)  0           conv2d_739[0][0]
#                                                                  conv2d_740[0][0]
#                                                                  conv2d_742[0][0]
#                                                                  conv2d_745[0][0]
# __________________________________________________________________________________________________
# conv2d_750 (Conv2D)             (None, 35, 35, 64)   24640       concatenate_95[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_76 (AveragePo (None, 35, 35, 384)  0           concatenate_95[0][0]
# __________________________________________________________________________________________________
# conv2d_748 (Conv2D)             (None, 35, 35, 64)   24640       concatenate_95[0][0]
# __________________________________________________________________________________________________
# conv2d_751 (Conv2D)             (None, 35, 35, 96)   55392       conv2d_750[0][0]
# __________________________________________________________________________________________________
# conv2d_746 (Conv2D)             (None, 35, 35, 96)   36960       average_pooling2d_76[0][0]
# __________________________________________________________________________________________________
# conv2d_747 (Conv2D)             (None, 35, 35, 96)   36960       concatenate_95[0][0]
# __________________________________________________________________________________________________
# conv2d_749 (Conv2D)             (None, 35, 35, 96)   55392       conv2d_748[0][0]
# __________________________________________________________________________________________________
# conv2d_752 (Conv2D)             (None, 35, 35, 96)   83040       conv2d_751[0][0]
# __________________________________________________________________________________________________
# concatenate_96 (Concatenate)    (None, 35, 35, 384)  0           conv2d_746[0][0]
#                                                                  conv2d_747[0][0]
#                                                                  conv2d_749[0][0]
#                                                                  conv2d_752[0][0]
# __________________________________________________________________________________________________
# conv2d_757 (Conv2D)             (None, 35, 35, 64)   24640       concatenate_96[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_77 (AveragePo (None, 35, 35, 384)  0           concatenate_96[0][0]
# __________________________________________________________________________________________________
# conv2d_755 (Conv2D)             (None, 35, 35, 64)   24640       concatenate_96[0][0]
# __________________________________________________________________________________________________
# conv2d_758 (Conv2D)             (None, 35, 35, 96)   55392       conv2d_757[0][0]
# __________________________________________________________________________________________________
# conv2d_753 (Conv2D)             (None, 35, 35, 96)   36960       average_pooling2d_77[0][0]
# __________________________________________________________________________________________________
# conv2d_754 (Conv2D)             (None, 35, 35, 96)   36960       concatenate_96[0][0]
# __________________________________________________________________________________________________
# conv2d_756 (Conv2D)             (None, 35, 35, 96)   55392       conv2d_755[0][0]
# __________________________________________________________________________________________________
# conv2d_759 (Conv2D)             (None, 35, 35, 96)   83040       conv2d_758[0][0]
# __________________________________________________________________________________________________
# concatenate_97 (Concatenate)    (None, 35, 35, 384)  0           conv2d_753[0][0]
#                                                                  conv2d_754[0][0]
#                                                                  conv2d_756[0][0]
#                                                                  conv2d_759[0][0]
# __________________________________________________________________________________________________
# conv2d_761 (Conv2D)             (None, 35, 35, 192)  73920       concatenate_97[0][0]
# __________________________________________________________________________________________________
# conv2d_762 (Conv2D)             (None, 35, 35, 224)  387296      conv2d_761[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 17, 17, 384)  0           concatenate_97[0][0]
# __________________________________________________________________________________________________
# conv2d_760 (Conv2D)             (None, 17, 17, 384)  1327488     concatenate_97[0][0]
# __________________________________________________________________________________________________
# conv2d_763 (Conv2D)             (None, 17, 17, 256)  516352      conv2d_762[0][0]
# __________________________________________________________________________________________________
# concatenate_98 (Concatenate)    (None, 17, 17, 1024) 0           max_pooling2d_18[0][0]
#                                                                  conv2d_760[0][0]
#                                                                  conv2d_763[0][0]
# __________________________________________________________________________________________________
# conv2d_769 (Conv2D)             (None, 17, 17, 192)  196800      concatenate_98[0][0]
# __________________________________________________________________________________________________
# conv2d_770 (Conv2D)             (None, 17, 17, 192)  258240      conv2d_769[0][0]
# __________________________________________________________________________________________________
# conv2d_766 (Conv2D)             (None, 17, 17, 192)  196800      concatenate_98[0][0]
# __________________________________________________________________________________________________
# conv2d_771 (Conv2D)             (None, 17, 17, 224)  301280      conv2d_770[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_78 (AveragePo (None, 17, 17, 1024) 0           concatenate_98[0][0]
# __________________________________________________________________________________________________
# conv2d_767 (Conv2D)             (None, 17, 17, 224)  301280      conv2d_766[0][0]
# __________________________________________________________________________________________________
# conv2d_772 (Conv2D)             (None, 17, 17, 224)  351456      conv2d_771[0][0]
# __________________________________________________________________________________________________
# conv2d_764 (Conv2D)             (None, 17, 17, 128)  131200      average_pooling2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_765 (Conv2D)             (None, 17, 17, 384)  393600      concatenate_98[0][0]
# __________________________________________________________________________________________________
# conv2d_768 (Conv2D)             (None, 17, 17, 256)  401664      conv2d_767[0][0]
# __________________________________________________________________________________________________
# conv2d_773 (Conv2D)             (None, 17, 17, 256)  401664      conv2d_772[0][0]
# __________________________________________________________________________________________________
# concatenate_99 (Concatenate)    (None, 17, 17, 1024) 0           conv2d_764[0][0]
#                                                                  conv2d_765[0][0]
#                                                                  conv2d_768[0][0]
#                                                                  conv2d_773[0][0]
# __________________________________________________________________________________________________
# conv2d_779 (Conv2D)             (None, 17, 17, 192)  196800      concatenate_99[0][0]
# __________________________________________________________________________________________________
# conv2d_780 (Conv2D)             (None, 17, 17, 192)  258240      conv2d_779[0][0]
# __________________________________________________________________________________________________
# conv2d_776 (Conv2D)             (None, 17, 17, 192)  196800      concatenate_99[0][0]
# __________________________________________________________________________________________________
# conv2d_781 (Conv2D)             (None, 17, 17, 224)  301280      conv2d_780[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_79 (AveragePo (None, 17, 17, 1024) 0           concatenate_99[0][0]
# __________________________________________________________________________________________________
# conv2d_777 (Conv2D)             (None, 17, 17, 224)  301280      conv2d_776[0][0]
# __________________________________________________________________________________________________
# conv2d_782 (Conv2D)             (None, 17, 17, 224)  351456      conv2d_781[0][0]
# __________________________________________________________________________________________________
# conv2d_774 (Conv2D)             (None, 17, 17, 128)  131200      average_pooling2d_79[0][0]
# __________________________________________________________________________________________________
# conv2d_775 (Conv2D)             (None, 17, 17, 384)  393600      concatenate_99[0][0]
# __________________________________________________________________________________________________
# conv2d_778 (Conv2D)             (None, 17, 17, 256)  401664      conv2d_777[0][0]
# __________________________________________________________________________________________________
# conv2d_783 (Conv2D)             (None, 17, 17, 256)  401664      conv2d_782[0][0]
# __________________________________________________________________________________________________
# concatenate_100 (Concatenate)   (None, 17, 17, 1024) 0           conv2d_774[0][0]
#                                                                  conv2d_775[0][0]
#                                                                  conv2d_778[0][0]
#                                                                  conv2d_783[0][0]
# __________________________________________________________________________________________________
# conv2d_789 (Conv2D)             (None, 17, 17, 192)  196800      concatenate_100[0][0]
# __________________________________________________________________________________________________
# conv2d_790 (Conv2D)             (None, 17, 17, 192)  258240      conv2d_789[0][0]
# __________________________________________________________________________________________________
# conv2d_786 (Conv2D)             (None, 17, 17, 192)  196800      concatenate_100[0][0]
# __________________________________________________________________________________________________
# conv2d_791 (Conv2D)             (None, 17, 17, 224)  301280      conv2d_790[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_80 (AveragePo (None, 17, 17, 1024) 0           concatenate_100[0][0]
# __________________________________________________________________________________________________
# conv2d_787 (Conv2D)             (None, 17, 17, 224)  301280      conv2d_786[0][0]
# __________________________________________________________________________________________________
# conv2d_792 (Conv2D)             (None, 17, 17, 224)  351456      conv2d_791[0][0]
# __________________________________________________________________________________________________
# conv2d_784 (Conv2D)             (None, 17, 17, 128)  131200      average_pooling2d_80[0][0]
# __________________________________________________________________________________________________
# conv2d_785 (Conv2D)             (None, 17, 17, 384)  393600      concatenate_100[0][0]
# __________________________________________________________________________________________________
# conv2d_788 (Conv2D)             (None, 17, 17, 256)  401664      conv2d_787[0][0]
# __________________________________________________________________________________________________
# conv2d_793 (Conv2D)             (None, 17, 17, 256)  401664      conv2d_792[0][0]
# __________________________________________________________________________________________________
# concatenate_101 (Concatenate)   (None, 17, 17, 1024) 0           conv2d_784[0][0]
#                                                                  conv2d_785[0][0]
#                                                                  conv2d_788[0][0]
#                                                                  conv2d_793[0][0]
# __________________________________________________________________________________________________
# conv2d_799 (Conv2D)             (None, 17, 17, 192)  196800      concatenate_101[0][0]
# __________________________________________________________________________________________________
# conv2d_800 (Conv2D)             (None, 17, 17, 192)  258240      conv2d_799[0][0]
# __________________________________________________________________________________________________
# conv2d_796 (Conv2D)             (None, 17, 17, 192)  196800      concatenate_101[0][0]
# __________________________________________________________________________________________________
# conv2d_801 (Conv2D)             (None, 17, 17, 224)  301280      conv2d_800[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_81 (AveragePo (None, 17, 17, 1024) 0           concatenate_101[0][0]
# __________________________________________________________________________________________________
# conv2d_797 (Conv2D)             (None, 17, 17, 224)  301280      conv2d_796[0][0]
# __________________________________________________________________________________________________
# conv2d_802 (Conv2D)             (None, 17, 17, 224)  351456      conv2d_801[0][0]
# __________________________________________________________________________________________________
# conv2d_794 (Conv2D)             (None, 17, 17, 128)  131200      average_pooling2d_81[0][0]
# __________________________________________________________________________________________________
# conv2d_795 (Conv2D)             (None, 17, 17, 384)  393600      concatenate_101[0][0]
# __________________________________________________________________________________________________
# conv2d_798 (Conv2D)             (None, 17, 17, 256)  401664      conv2d_797[0][0]
# __________________________________________________________________________________________________
# conv2d_803 (Conv2D)             (None, 17, 17, 256)  401664      conv2d_802[0][0]
# __________________________________________________________________________________________________
# concatenate_102 (Concatenate)   (None, 17, 17, 1024) 0           conv2d_794[0][0]
#                                                                  conv2d_795[0][0]
#                                                                  conv2d_798[0][0]
#                                                                  conv2d_803[0][0]
# __________________________________________________________________________________________________
# conv2d_809 (Conv2D)             (None, 17, 17, 192)  196800      concatenate_102[0][0]
# __________________________________________________________________________________________________
# conv2d_810 (Conv2D)             (None, 17, 17, 192)  258240      conv2d_809[0][0]
# __________________________________________________________________________________________________
# conv2d_806 (Conv2D)             (None, 17, 17, 192)  196800      concatenate_102[0][0]
# __________________________________________________________________________________________________
# conv2d_811 (Conv2D)             (None, 17, 17, 224)  301280      conv2d_810[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_82 (AveragePo (None, 17, 17, 1024) 0           concatenate_102[0][0]
# __________________________________________________________________________________________________
# conv2d_807 (Conv2D)             (None, 17, 17, 224)  301280      conv2d_806[0][0]
# __________________________________________________________________________________________________
# conv2d_812 (Conv2D)             (None, 17, 17, 224)  351456      conv2d_811[0][0]
# __________________________________________________________________________________________________
# conv2d_804 (Conv2D)             (None, 17, 17, 128)  131200      average_pooling2d_82[0][0]
# __________________________________________________________________________________________________
# conv2d_805 (Conv2D)             (None, 17, 17, 384)  393600      concatenate_102[0][0]
# __________________________________________________________________________________________________
# conv2d_808 (Conv2D)             (None, 17, 17, 256)  401664      conv2d_807[0][0]
# __________________________________________________________________________________________________
# conv2d_813 (Conv2D)             (None, 17, 17, 256)  401664      conv2d_812[0][0]
# __________________________________________________________________________________________________
# concatenate_103 (Concatenate)   (None, 17, 17, 1024) 0           conv2d_804[0][0]
#                                                                  conv2d_805[0][0]
#                                                                  conv2d_808[0][0]
#                                                                  conv2d_813[0][0]
# __________________________________________________________________________________________________
# conv2d_819 (Conv2D)             (None, 17, 17, 192)  196800      concatenate_103[0][0]
# __________________________________________________________________________________________________
# conv2d_820 (Conv2D)             (None, 17, 17, 192)  258240      conv2d_819[0][0]
# __________________________________________________________________________________________________
# conv2d_816 (Conv2D)             (None, 17, 17, 192)  196800      concatenate_103[0][0]
# __________________________________________________________________________________________________
# conv2d_821 (Conv2D)             (None, 17, 17, 224)  301280      conv2d_820[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_83 (AveragePo (None, 17, 17, 1024) 0           concatenate_103[0][0]
# __________________________________________________________________________________________________
# conv2d_817 (Conv2D)             (None, 17, 17, 224)  301280      conv2d_816[0][0]
# __________________________________________________________________________________________________
# conv2d_822 (Conv2D)             (None, 17, 17, 224)  351456      conv2d_821[0][0]
# __________________________________________________________________________________________________
# conv2d_814 (Conv2D)             (None, 17, 17, 128)  131200      average_pooling2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_815 (Conv2D)             (None, 17, 17, 384)  393600      concatenate_103[0][0]
# __________________________________________________________________________________________________
# conv2d_818 (Conv2D)             (None, 17, 17, 256)  401664      conv2d_817[0][0]
# __________________________________________________________________________________________________
# conv2d_823 (Conv2D)             (None, 17, 17, 256)  401664      conv2d_822[0][0]
# __________________________________________________________________________________________________
# concatenate_104 (Concatenate)   (None, 17, 17, 1024) 0           conv2d_814[0][0]
#                                                                  conv2d_815[0][0]
#                                                                  conv2d_818[0][0]
#                                                                  conv2d_823[0][0]
# __________________________________________________________________________________________________
# conv2d_829 (Conv2D)             (None, 17, 17, 192)  196800      concatenate_104[0][0]
# __________________________________________________________________________________________________
# conv2d_830 (Conv2D)             (None, 17, 17, 192)  258240      conv2d_829[0][0]
# __________________________________________________________________________________________________
# conv2d_826 (Conv2D)             (None, 17, 17, 192)  196800      concatenate_104[0][0]
# __________________________________________________________________________________________________
# conv2d_831 (Conv2D)             (None, 17, 17, 224)  301280      conv2d_830[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_84 (AveragePo (None, 17, 17, 1024) 0           concatenate_104[0][0]
# __________________________________________________________________________________________________
# conv2d_827 (Conv2D)             (None, 17, 17, 224)  301280      conv2d_826[0][0]
# __________________________________________________________________________________________________
# conv2d_832 (Conv2D)             (None, 17, 17, 224)  351456      conv2d_831[0][0]
# __________________________________________________________________________________________________
# conv2d_824 (Conv2D)             (None, 17, 17, 128)  131200      average_pooling2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_825 (Conv2D)             (None, 17, 17, 384)  393600      concatenate_104[0][0]
# __________________________________________________________________________________________________
# conv2d_828 (Conv2D)             (None, 17, 17, 256)  401664      conv2d_827[0][0]
# __________________________________________________________________________________________________
# conv2d_833 (Conv2D)             (None, 17, 17, 256)  401664      conv2d_832[0][0]
# __________________________________________________________________________________________________
# concatenate_105 (Concatenate)   (None, 17, 17, 1024) 0           conv2d_824[0][0]
#                                                                  conv2d_825[0][0]
#                                                                  conv2d_828[0][0]
#                                                                  conv2d_833[0][0]
# __________________________________________________________________________________________________
# conv2d_839 (Conv2D)             (None, 17, 17, 384)  393600      concatenate_105[0][0]
# __________________________________________________________________________________________________
# conv2d_840 (Conv2D)             (None, 17, 17, 448)  516544      conv2d_839[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_85 (AveragePo (None, 17, 17, 1024) 0           concatenate_105[0][0]
# __________________________________________________________________________________________________
# conv2d_836 (Conv2D)             (None, 17, 17, 384)  393600      concatenate_105[0][0]
# __________________________________________________________________________________________________
# conv2d_841 (Conv2D)             (None, 17, 17, 512)  688640      conv2d_840[0][0]
# __________________________________________________________________________________________________
# conv2d_834 (Conv2D)             (None, 17, 17, 256)  262400      average_pooling2d_85[0][0]
# __________________________________________________________________________________________________
# conv2d_835 (Conv2D)             (None, 17, 17, 256)  262400      concatenate_105[0][0]
# __________________________________________________________________________________________________
# conv2d_837 (Conv2D)             (None, 17, 17, 256)  295168      conv2d_836[0][0]
# __________________________________________________________________________________________________
# conv2d_838 (Conv2D)             (None, 17, 17, 256)  295168      conv2d_836[0][0]
# __________________________________________________________________________________________________
# conv2d_842 (Conv2D)             (None, 17, 17, 256)  393472      conv2d_841[0][0]
# __________________________________________________________________________________________________
# conv2d_843 (Conv2D)             (None, 17, 17, 256)  393472      conv2d_841[0][0]
# __________________________________________________________________________________________________
# concatenate_106 (Concatenate)   (None, 17, 17, 1536) 0           conv2d_834[0][0]
#                                                                  conv2d_835[0][0]
#                                                                  conv2d_837[0][0]
#                                                                  conv2d_838[0][0]
#                                                                  conv2d_842[0][0]
#                                                                  conv2d_843[0][0]
# __________________________________________________________________________________________________
# conv2d_849 (Conv2D)             (None, 17, 17, 384)  590208      concatenate_106[0][0]
# __________________________________________________________________________________________________
# conv2d_850 (Conv2D)             (None, 17, 17, 448)  516544      conv2d_849[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_86 (AveragePo (None, 17, 17, 1536) 0           concatenate_106[0][0]
# __________________________________________________________________________________________________
# conv2d_846 (Conv2D)             (None, 17, 17, 384)  590208      concatenate_106[0][0]
# __________________________________________________________________________________________________
# conv2d_851 (Conv2D)             (None, 17, 17, 512)  688640      conv2d_850[0][0]
# __________________________________________________________________________________________________
# conv2d_844 (Conv2D)             (None, 17, 17, 256)  393472      average_pooling2d_86[0][0]
# __________________________________________________________________________________________________
# conv2d_845 (Conv2D)             (None, 17, 17, 256)  393472      concatenate_106[0][0]
# __________________________________________________________________________________________________
# conv2d_847 (Conv2D)             (None, 17, 17, 256)  295168      conv2d_846[0][0]
# __________________________________________________________________________________________________
# conv2d_848 (Conv2D)             (None, 17, 17, 256)  295168      conv2d_846[0][0]
# __________________________________________________________________________________________________
# conv2d_852 (Conv2D)             (None, 17, 17, 256)  393472      conv2d_851[0][0]
# __________________________________________________________________________________________________
# conv2d_853 (Conv2D)             (None, 17, 17, 256)  393472      conv2d_851[0][0]
# __________________________________________________________________________________________________
# concatenate_107 (Concatenate)   (None, 17, 17, 1536) 0           conv2d_844[0][0]
#                                                                  conv2d_845[0][0]
#                                                                  conv2d_847[0][0]
#                                                                  conv2d_848[0][0]
#                                                                  conv2d_852[0][0]
#                                                                  conv2d_853[0][0]
# __________________________________________________________________________________________________
# conv2d_859 (Conv2D)             (None, 17, 17, 384)  590208      concatenate_107[0][0]
# __________________________________________________________________________________________________
# conv2d_860 (Conv2D)             (None, 17, 17, 448)  516544      conv2d_859[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_87 (AveragePo (None, 17, 17, 1536) 0           concatenate_107[0][0]
# __________________________________________________________________________________________________
# conv2d_856 (Conv2D)             (None, 17, 17, 384)  590208      concatenate_107[0][0]
# __________________________________________________________________________________________________
# conv2d_861 (Conv2D)             (None, 17, 17, 512)  688640      conv2d_860[0][0]
# __________________________________________________________________________________________________
# conv2d_854 (Conv2D)             (None, 17, 17, 256)  393472      average_pooling2d_87[0][0]
# __________________________________________________________________________________________________
# conv2d_855 (Conv2D)             (None, 17, 17, 256)  393472      concatenate_107[0][0]
# __________________________________________________________________________________________________
# conv2d_857 (Conv2D)             (None, 17, 17, 256)  295168      conv2d_856[0][0]
# __________________________________________________________________________________________________
# conv2d_858 (Conv2D)             (None, 17, 17, 256)  295168      conv2d_856[0][0]
# __________________________________________________________________________________________________
# conv2d_862 (Conv2D)             (None, 17, 17, 256)  393472      conv2d_861[0][0]
# __________________________________________________________________________________________________
# conv2d_863 (Conv2D)             (None, 17, 17, 256)  393472      conv2d_861[0][0]
# __________________________________________________________________________________________________
# concatenate_108 (Concatenate)   (None, 17, 17, 1536) 0           conv2d_854[0][0]
#                                                                  conv2d_855[0][0]
#                                                                  conv2d_857[0][0]
#                                                                  conv2d_858[0][0]
#                                                                  conv2d_862[0][0]
#                                                                  conv2d_863[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_88 (AveragePo (None, 8, 8, 1536)   0           concatenate_108[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 98304)        0           average_pooling2d_88[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1536)         150996480   flatten_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 1536)         0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 2)            3074        dropout_3[0][0]
# ==================================================================================================
# Total params: 188,709,570
# Trainable params: 188,709,570
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, 
           to_file='model.pdf', 
           show_shapes=True, 
           show_layer_names=False,
           rankdir='TB')
